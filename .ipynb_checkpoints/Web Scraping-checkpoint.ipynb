# %%
from googleapiclient.discovery import build
from bs4 import BeautifulSoup
import requests
import networkx as nx
import matplotlib.pyplot as plt
from pyvis.network import Network
import pickle
import difflib
import re

# %%
# API and Search Keys
my_api_key = "AIzaSyBRvu5CNwemS1HV3IcQ1bcCnfS30yUaiEM"
my_cse_id = "7191dc5676ef525ac"

# Gets google search page, given search term (CHANGED 01/17)
def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    url = res["items"][0]["link"]
    url = url + "/userrecs"
    return res

# %%
# Example of google_search usage
#results = google_search("Attack on Titan MAL", my_api_key, my_cse_id)

# %%
# Scrapes the recommendation page from the MAL User Recommendation page for the given anime (CHANGED 01/17)
def get_name(link):
    resp = requests.get(link)
    parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
    soup = BeautifulSoup(resp.content, parser)
    if(soup.select(".title-inherit")):
        name = soup.select(".title-inherit")
    else:
        name = soup.select(".h1_bold_none strong")
    print(name)
    nm = name[0].text
    return nm

def get_category(link):
    resp = requests.get(link)
    parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
    soup = BeautifulSoup(resp.content, parser)
    cat = soup.select("span+ a:nth-child(3)")
    ct = cat[0].text
    return ct

def get_rec_links(rec_url, threshold):
    resp = requests.get(rec_url)
    parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
    soup = BeautifulSoup(resp.content, parser)
    votes = soup.select(".js-similar-recommendations-button strong")
    total_votes = [int(i.text) for i in votes if int(i.text)>=threshold]
    l = list()
    check = 0
    for link in soup.find_all('a', href=True):
        if(str(link['href']).startswith("/myrecommendations")):
            check = 1
            #print("I work")
        if(check == 1):
            if(link['href'] == "https://myanimelist.net/topanime.php"):
                break
            z = re.search("https://myanimelist\.net/anime/\d*/(.*)$", link['href'])
            if(z):
                if(link["href"] not in l):
                    l.append(link["href"])
    rec_links = l[0:len(total_votes)]
    return rec_links

def searchRecs(res, anime):
    if(anime == "Boku no Hero Academia"):
        url = "https://myanimelist.net/anime/31964/Boku_no_Hero_Academia/userrecs"
    elif(anime == "JoJo no Kimyou na Bouken TV"):
        url = "https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV/userrecs"
    else:
        url = res["items"][0]["link"]
        url = url + "/userrecs"
    #print("Step 0")
    rec_links = get_rec_links(url, 10)
    #print("Step 1")
    #print(rec_links)
    anime_name = get_name(url)
    # connect to webpage
    resp = requests.get(url)
    # get BeautifulSoup object
    soup = BeautifulSoup(resp.content, 'html.parser')
    # Get the titles of the user recommended animes
    #links = soup.select("#content div:nth-child(2) strong")
    #recs = [title.text for title in links]
    # Get the upvotes for the given recommendations
    #votes = soup.select(".js-similar-recommendations-button strong")
    # Only keep those that were upvoted at least 5 times
    #total_votes = [int(i.text) for i in votes if int(i.text)>=10]
    rec_names = [get_name(a) for a in rec_links]
    #print("Step 2")
    #total_recs = rec_names[0:len(total_votes)]
    ani_recs[anime_name] = rec_names

# %%
ani_recs = dict()
ani_list_pt1 = ["Attack on Titan", "Fullmetal Alchemist Brotherhood", "Haikyuu", "Demon Slayer", "Hunter x Hunter 2011",
           "Noragami", "One Piece", "Kono Suba", "Cowboy Bepop", "Vinland Saga"] 
ani_list_pt2 = ["Code Geass", "Great Teacher Onizuka", "Mushishi", "Boku no Hero Academia", "One Punch Man", "Tokyo Ghoul"] 
ani_list_pt3 =["Bleach", "Mob Psycho 100", "Psycho-Pass","Fate Zero", "JoJo no Kimyou na Bouken TV", "Oregairu"] 
ani_list_pt4 = ["Seishun Buta Yarou", "Love is War", "Kuroko no Basket", "Gintama", "Baccano!", "Kekkai Sensen", "Steins Gate"]
ani_list_pt5 =["March Comes in Like a Lion", "Your Lie in April","Monster", "Re:Zero", "Death Note"]
ani_list = ["Great Teacher Onizuka"]

for anime in ani_list_pt1:
    anime_search = anime + " MAL"
    if(anime == "Boku no Hero Academia"):
        url = "https://myanimelist.net/anime/31964/Boku_no_Hero_Academia/userrecs"
    elif(anime == "JoJo no Kimyou na Bouken TV"):
        url = "https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV/userrecs"
    else:
        url = google_search(anime_search, my_api_key, my_cse_id)
    searchRecs(url, anime)
    print(anime, "Done")
# Out:
# [<p class="title-english title-inherit">Attack on Titan</p>]
# [<p class="title-english title-inherit">Kabaneri of the Iron Fortress</p>]
# [<p class="title-english title-inherit">Seraph of the End: Vampire Reign</p>]
# [<strong>Black Bullet</strong>]
# [<p class="title-english title-inherit">The Promised Neverland</p>]
# [<strong>Tokyo Ghoul</strong>]
# [<p class="title-english title-inherit">Knights of Sidonia</p>]
# [<strong>Fullmetal Alchemist: Brotherhood</strong>]
# [<strong>Claymore</strong>]
# [<strong>God Eater</strong>]
# [<strong>Aldnoah.Zero</strong>]
# [<strong>Neon Genesis Evangelion</strong>]
# [<strong>Akame ga Kill!</strong>]
# [<strong>Deadman Wonderland</strong>]
# [<p class="title-english title-inherit">Demon Slayer: Kimetsu no Yaiba</p>]
# [<strong>Vinland Saga</strong>]
# [<p class="title-english title-inherit">Berserk</p>]
# [<strong>Highschool of the Dead</strong>]
# [<p class="title-english title-inherit">Gurren Lagann</p>]
# Attack on Titan Done
# [<strong>Fullmetal Alchemist: Brotherhood</strong>]
# [<p class="title-english title-inherit">Hunter x Hunter</p>]
# [<p class="title-english title-inherit">Attack on Titan</p>]
# [<strong>D.Gray-man</strong>]
# [<p class="title-english title-inherit">Blue Exorcist</p>]
# [<p class="title-english title-inherit">Code Geass: Lelouch of the Rebellion</p>]
# [<strong>Baccano!</strong>]
# [<p class="title-english title-inherit">Demon Slayer: Kimetsu no Yaiba</p>]
# Fullmetal Alchemist Brotherhood Done
# [<p class="title-english title-inherit">Haikyu!!</p>]
# [<p class="title-english title-inherit">Kuroko's Basketball</p>]
# [<p class="title-english title-inherit">Ace of Diamond</p>]
# [<p class="title-english title-inherit">My Hero Academia</p>]
# [<p class="title-english title-inherit">Run with the Wind</p>]
# [<p class="title-english title-inherit">Free! - Iwatobi Swim Club</p>]
# [<strong>Ahiru no Sora</strong>]
# [<strong>Yowamushi Pedal</strong>]
# [<p class="title-english title-inherit">Big Windup!</p>]
# [<p class="title-english title-inherit">Welcome to the Ballroom</p>]
# [<strong>Chihayafuru</strong>]
# Haikyuu Done
# [<p class="title-english title-inherit">Demon Slayer: Kimetsu no Yaiba</p>]
# [<strong>Dororo</strong>]
# [<strong>Jujutsu Kaisen (TV)</strong>]
# [<strong>Bleach</strong>]
# [<p class="title-english title-inherit">Attack on Titan</p>]
# [<strong>Fullmetal Alchemist: Brotherhood</strong>]
# [<p class="title-english title-inherit">Hunter x Hunter</p>]
# Demon Slayer Done
# [<p class="title-english title-inherit">Hunter x Hunter</p>]
# [<strong>Fullmetal Alchemist: Brotherhood</strong>]
# [<strong>One Piece</strong>]
# [<p class="title-english title-inherit">Yu Yu Hakusho: Ghost Files</p>]
# [<strong>Naruto</strong>]
# [<strong>Made in Abyss</strong>]
# [<p class="title-english title-inherit">Tower of God</p>]
# [<p class="title-english title-inherit">JoJo's Bizarre Adventure</p>]
# [<p class="title-english title-inherit">My Hero Academia</p>]
# [<strong>Magi: The Labyrinth of Magic</strong>]
# [<p class="title-english title-inherit">Naruto: Shippuden</p>]
# [<strong>Dragon Ball</strong>]
# [<p class="title-english title-inherit">JoJo's Bizarre Adventure: Stardust Crusaders</p>]
# [<p class="title-english title-inherit">Demon Slayer: Kimetsu no Yaiba</p>]
# Hunter x Hunter 2011 Done
# [<p class="title-english title-inherit">Noragami: Stray God</p>]
# [<p class="title-english title-inherit">Kamisama Kiss</p>]
# [<p class="title-english title-inherit">Blue Exorcist</p>]
# [<p class="title-english title-inherit">Beyond the Boundary</p>]
# [<p class="title-english title-inherit">The Devil is a Part-Timer!</p>]
# [<strong>Soul Eater</strong>]
# [<strong>Blood Lad</strong>]
# [<p class="title-english title-inherit">Toilet-bound Hanako-kun</p>]
# [<strong>Bakemonogatari</strong>]
# [<p class="title-english title-inherit">Rurouni Kenshin</p>]
# Noragami Done
# [<strong>One Piece</strong>]
# [<strong>Fairy Tail</strong>]
# [<p class="title-english title-inherit">Hunter x Hunter</p>]
# [<strong>Naruto</strong>]
# [<strong>Dragon Ball</strong>]
# [<strong>Dragon Ball Z</strong>]
# [<p class="title-english title-inherit">Naruto: Shippuden</p>]
# [<strong>Toriko</strong>]
# [<strong>Soul Eater</strong>]
# [<strong>Bleach</strong>]
# One Piece Done
# [<p class="title-english title-inherit">KonoSuba: God's Blessing on This Wonderful World!</p>]
# [<p class="title-english title-inherit">Re:ZERO -Starting Life in Another World-</p>]
# [<p class="title-english title-inherit">Is It Wrong to Try to Pick Up Girls in a Dungeon?</p>]
# [<p class="title-english title-inherit">Cautious Hero: The Hero Is Overpowered but Overly Cautious</p>]
# [<p class="title-english title-inherit">No Game, No Life</p>]
# [<p class="title-english title-inherit">In Another World With My Smartphone</p>]
# [<strong>Princess Connect! Re:Dive</strong>]
# [<strong>Sword Art Online</strong>]
# Kono Suba Done
# [<strong>Cowboy Bebop</strong>]
# [<strong>Samurai Champloo</strong>]
# [<strong>Trigun</strong>]
# [<strong>Black Lagoon</strong>]
# [<p class="title-english title-inherit">Outlaw Star</p>]
# [<p class="title-english title-inherit">Space Dandy</p>]
# [<strong>Baccano!</strong>]
# [<p class="title-english title-inherit">Michiko &amp; Hatchin</p>]
# [<p class="title-english title-inherit">Darker than Black</p>]
# [<strong>Psycho-Pass</strong>]
# [<strong>Gintama</strong>]
# Cowboy Bepop Done
# [<strong>Vinland Saga</strong>]
# [<p class="title-english title-inherit">Attack on Titan</p>]
# Vinland Saga Done

# %%
for anime in ani_list_pt2:
    anime_search = anime + " MAL"
    if(anime == "Boku no Hero Academia"):
        url = "https://myanimelist.net/anime/31964/Boku_no_Hero_Academia/userrecs"
    elif(anime == "JoJo no Kimyou na Bouken TV"):
        url = "https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV/userrecs"
    else:
        url = google_search(anime_search, my_api_key, my_cse_id)
    searchRecs(url, anime)
    print(anime, "Done")
# Out:
# [<p class="title-english title-inherit">Code Geass: Lelouch of the Rebellion</p>]
# [<strong>Death Note</strong>]
# [<strong>Guilty Crown</strong>]
# [<strong>Aldnoah.Zero</strong>]
# [<p class="title-english title-inherit">No Game, No Life</p>]
# [<strong>Mobile Suit Gundam 00</strong>]
# [<p class="title-english title-inherit">Legend of the Galactic Heroes</p>]
# [<p class="title-english title-inherit">Valvrave the Liberator</p>]
# [<p class="title-english title-inherit">Gurren Lagann</p>]
# [<strong>Fullmetal Alchemist: Brotherhood</strong>]
# [<p class="title-english title-inherit">Darker than Black</p>]
# [<strong>Big Order (TV)</strong>]
# [<strong>Mobile Suit Gundam SEED</strong>]
# [<strong>Neon Genesis Evangelion</strong>]
# [<p class="title-english title-inherit">Terror in Resonance</p>]
# [<p class="title-english title-inherit">Eureka Seven</p>]
# [<strong>Full Metal Panic!</strong>]
# [<strong>Akame ga Kill!</strong>]
# Code Geass Done
# [<strong>Great Teacher Onizuka</strong>]
# [<strong>Golden Boy</strong>]
# [<p class="title-english title-inherit">Assassination Classroom</p>]
# [<strong>Gintama</strong>]
# [<p class="title-english title-inherit">The Gokusen</p>]
# Great Teacher Onizuka Done
# [<p class="title-english title-inherit">Mushi-Shi</p>]
# [<p class="title-english title-inherit">Natsume's Book of Friends</p>]
# [<p class="title-english title-inherit">Kino's Journey</p>]
# [<strong>Mononoke</strong>]
# [<p class="title-english title-inherit">Princess Mononoke</p>]
# [<strong>xxxHOLiC</strong>]
# [<strong>Aria the Animation</strong>]
# Mushishi Done
# [<p class="title-english title-inherit">My Hero Academia</p>]
# [<strong>One Punch Man</strong>]
# [<strong>Black Clover</strong>]
# [<strong>Naruto</strong>]
# [<p class="title-english title-inherit">Assassination Classroom</p>]
# [<p class="title-english title-inherit">Haikyu!!</p>]
# [<p class="title-english title-inherit">Hunter x Hunter</p>]
# [<strong>Tiger &amp; Bunny</strong>]
# [<p class="title-english title-inherit">Little Witch Academia</p>]
# [<strong>Charlotte</strong>]
# [<p class="title-english title-inherit">Fire Force</p>]
# Boku no Hero Academia Done
# [<strong>One Punch Man</strong>]
# [<strong>Mob Psycho 100</strong>]
# [<p class="title-english title-inherit">My Hero Academia</p>]
# [<p class="title-english title-inherit">The Disastrous Life of Saiki K.</p>]
# [<strong>Overlord</strong>]
# [<strong>Gintama</strong>]
# [<p class="title-english title-inherit">The Devil is a Part-Timer!</p>]
# One Punch Man Done
# [<strong>Tokyo Ghoul</strong>]
# [<p class="title-english title-inherit">Parasyte -the maxim-</p>]
# [<p class="title-english title-inherit">Ajin: Demi-Human</p>]
# [<p class="title-english title-inherit">Attack on Titan</p>]
# [<strong>Deadman Wonderland</strong>]
# [<strong>Shiki</strong>]
# [<p class="title-english title-inherit">Devils' Line</p>]
# [<strong>Pupa</strong>]
# [<strong>Akame ga Kill!</strong>]
# Tokyo Ghoul Done

# %%
for anime in ani_list_pt3:
    anime_search = anime + " MAL"
    if(anime == "Boku no Hero Academia"):
        url = "https://myanimelist.net/anime/31964/Boku_no_Hero_Academia/userrecs"
    elif(anime == "JoJo no Kimyou na Bouken TV"):
        url = "https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV/userrecs"
    else:
        url = google_search(anime_search, my_api_key, my_cse_id)
    searchRecs(url, anime)
    print(anime, "Done")
# Out:
# [<strong>Bleach</strong>]
# [<p class="title-english title-inherit">Yu Yu Hakusho: Ghost Files</p>]
# [<p class="title-english title-inherit">Naruto: Shippuden</p>]
# [<strong>Naruto</strong>]
# [<strong>D.Gray-man</strong>]
# [<strong>Soul Eater</strong>]
# [<p class="title-english title-inherit">Buso Renkin</p>]
# [<strong>Claymore</strong>]
# [<p class="title-english title-inherit">Demon Slayer: Kimetsu no Yaiba</p>]
# [<strong>One Piece</strong>]
# Bleach Done
# [<strong>Mob Psycho 100</strong>]
# [<strong>One Punch Man</strong>]
# [<p class="title-english title-inherit">The Disastrous Life of Saiki K.</p>]
# [<strong>Hinamatsuri</strong>]
# Mob Psycho 100 Done
# [<strong>Psycho-Pass</strong>]
# [<strong>Death Note</strong>]
# [<p class="title-english title-inherit">Ghost in the Shell: Stand Alone Complex</p>]
# [<p class="title-english title-inherit">From the New World</p>]
# [<strong>Ergo Proxy</strong>]
# [<strong>Id:Invaded</strong>]
# [<p class="title-english title-inherit">Terror in Resonance</p>]
# [<p class="title-english title-inherit">Ghost in the Shell</p>]
# [<strong>Death Parade</strong>]
# [<strong>Monster</strong>]
# [<strong>Cowboy Bebop</strong>]
# [<p class="title-english title-inherit">Darker than Black</p>]
# [<strong>B: The Beginning</strong>]
# Psycho-Pass Done
# [<strong>Fate/Zero</strong>]
# [<p class="title-english title-inherit">The Future Diary</p>]
# [<p class="title-english title-inherit">Puella Magi Madoka Magica</p>]
# [<p class="title-english title-inherit">the Garden of sinners Chapter 1: Overlooking View</p>]
# [<strong>Re:Creators</strong>]
# Fate Zero Done
# [<p class="title-english title-inherit">JoJo's Bizarre Adventure</p>]
# [<p class="title-english title-inherit">Hunter x Hunter</p>]
# [<p class="title-english title-inherit">Fist of the North Star</p>]
# [<p class="title-english title-inherit">Kaiji: Ultimate Survivor</p>]
# JoJo no Kimyou na Bouken TV Done
# [<p class="title-english title-inherit">My Teen Romantic Comedy SNAFU</p>]
# [<strong>Hyouka</strong>]
# [<p class="title-english title-inherit">Classroom of the Elite</p>]
# [<p class="title-english title-inherit">Haganai: I don't have many friends</p>]
# [<p class="title-english title-inherit">Rascal Does Not Dream of Bunny Girl Senpai</p>]
# [<strong>Bakemonogatari</strong>]
# [<strong>Toradora!</strong>]
# [<p class="title-english title-inherit">WataMote: No Matter How I Look At It, It's You Guys' Fault I'm Unpopular!</p>]
# [<p class="title-english title-inherit">Oreshura</p>]
# Oregairu Done

# %%
for anime in ani_list_pt4:
    anime_search = anime + " MAL"
    if(anime == "Boku no Hero Academia"):
        url = "https://myanimelist.net/anime/31964/Boku_no_Hero_Academia/userrecs"
    elif(anime == "JoJo no Kimyou na Bouken TV"):
        url = "https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV/userrecs"
    else:
        url = google_search(anime_search, my_api_key, my_cse_id)
    searchRecs(url, anime)
    print(anime, "Done")
# Out:
# [<p class="title-english title-inherit">Rascal Does Not Dream of Bunny Girl Senpai</p>]
# [<strong>Bakemonogatari</strong>]
# [<p class="title-english title-inherit">My Teen Romantic Comedy SNAFU</p>]
# [<strong>Kokoro Connect</strong>]
# [<p class="title-english title-inherit">The Melancholy of Haruhi Suzumiya</p>]
# [<strong>Clannad</strong>]
# Seishun Buta Yarou Done
# [<p class="title-english title-inherit">Kaguya-sama: Love is War</p>]
# [<p class="title-english title-inherit">Teasing Master Takagi-san</p>]
# [<strong>Death Note</strong>]
# [<p class="title-english title-inherit">Science Fell in Love, So I Tried to Prove It</p>]
# Love is War Done
# [<p class="title-english title-inherit">Kuroko's Basketball</p>]
# [<p class="title-english title-inherit">Haikyu!!</p>]
# [<p class="title-english title-inherit">Free! - Iwatobi Swim Club</p>]
# [<strong>Slam Dunk</strong>]
# [<p class="title-english title-inherit">The Prince of Tennis</p>]
# Kuroko no Basket Done
# [<strong>Gintama</strong>]
# [<strong>SKET Dance</strong>]
# [<p class="title-english title-inherit">Daily Lives of High School Boys</p>]
# [<p class="title-english title-inherit">The Disastrous Life of Saiki K.</p>]
# [<strong>Beelzebub</strong>]
# [<p class="title-english title-inherit">Rurouni Kenshin</p>]
# [<strong>One Punch Man</strong>]
# [<p class="title-english title-inherit">Hayate the Combat Butler</p>]
# [<strong>Great Teacher Onizuka</strong>]
# [<strong>Cowboy Bebop</strong>]
# [<p class="title-english title-inherit">Good Luck Girl!</p>]
# Gintama Done
# [<strong>Baccano!</strong>]
# [<strong>Durarara!!</strong>]
# [<strong>91 Days</strong>]
# [<strong>Cowboy Bebop</strong>]
# [<strong>Fullmetal Alchemist: Brotherhood</strong>]
# [<strong>Fullmetal Alchemist</strong>]
# [<strong>Black Lagoon</strong>]
# Baccano! Done
# [<p class="title-english title-inherit">Blood Blockade Battlefront</p>]
# [<p class="title-english title-inherit">Bungo Stray Dogs</p>]
# Kekkai Sensen Done
# [<strong>Steins;Gate</strong>]
# [<p class="title-english title-inherit">ERASED</p>]
# [<p class="title-english title-inherit">Re:ZERO -Starting Life in Another World-</p>]
# [<p class="title-english title-inherit">Puella Magi Madoka Magica</p>]
# [<p class="title-english title-inherit">The Future Diary</p>]
# [<p class="title-english title-inherit">The Girl Who Leapt Through Time</p>]
# [<p class="title-english title-inherit">Welcome to the N.H.K.</p>]
# [<p class="title-english title-inherit">When They Cry</p>]
# [<p class="title-english title-inherit">When They Cry: Kai</p>]
# [<strong>Death Note</strong>]
# [<p class="title-english title-inherit">Noein: to your other self</p>]
# Steins Gate Done

# %%
for anime in ani_list_pt5:
    anime_search = anime + " MAL"
    if(anime == "Boku no Hero Academia"):
        url = "https://myanimelist.net/anime/31964/Boku_no_Hero_Academia/userrecs"
    elif(anime == "JoJo no Kimyou na Bouken TV"):
        url = "https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV/userrecs"
    else:
        url = google_search(anime_search, my_api_key, my_cse_id)
    searchRecs(url, anime)
    print(anime, "Done")
# Out:
# [<p class="title-english title-inherit">March comes in like a lion</p>]
# [<p class="title-english title-inherit">Your Lie in April</p>]
# [<strong>Chihayafuru</strong>]
# [<p class="title-english title-inherit">Honey and Clover</p>]
# [<p class="title-english title-inherit">Natsume's Book of Friends</p>]
# March Comes in Like a Lion Done
# [<p class="title-english title-inherit">Your Lie in April</p>]
# [<p class="title-english title-inherit">March comes in like a lion</p>]
# [<strong>Nodame Cantabile</strong>]
# [<p class="title-english title-inherit">Clannad ~After Story~</p>]
# [<p class="title-english title-inherit">I want to eat your pancreas</p>]
# [<p class="title-english title-inherit">anohana: The Flower We Saw That Day</p>]
# [<p class="title-english title-inherit">Kids on the Slope</p>]
# [<strong>Plastic Memories</strong>]
# [<strong>Angel Beats!</strong>]
# [<strong>Violet Evergarden</strong>]
# [<strong>White Album 2</strong>]
# [<p class="title-english title-inherit">The Pet Girl of Sakurasou</p>]
# [<p class="title-english title-inherit">Sound! Euphonium</p>]
# Your Lie in April Done
# [<strong>Monster</strong>]
# [<strong>Death Note</strong>]
# [<strong>Psycho-Pass</strong>]
# [<p class="title-english title-inherit">Gankutsuou: The Count of Monte Cristo</p>]
# Monster Done
# [<p class="title-english title-inherit">Re:ZERO -Starting Life in Another World-</p>]
# [<strong>Steins;Gate</strong>]
# [<p class="title-english title-inherit">KonoSuba: God's Blessing on This Wonderful World!</p>]
# [<p class="title-english title-inherit">ERASED</p>]
# [<p class="title-english title-inherit">The Rising of the Shield Hero</p>]
# [<p class="title-english title-inherit">Puella Magi Madoka Magica</p>]
# [<p class="title-english title-inherit">When They Cry</p>]
# [<strong>Sword Art Online</strong>]
# Re:Zero Done
# [<strong>Death Note</strong>]
# [<p class="title-english title-inherit">Code Geass: Lelouch of the Rebellion</p>]
# [<strong>Monster</strong>]
# [<p class="title-english title-inherit">Terror in Resonance</p>]
# [<p class="title-english title-inherit">The Future Diary</p>]
# [<strong>Psycho-Pass</strong>]
# [<p class="title-english title-inherit">Code Geass: Lelouch of the Rebellion R2</p>]
# [<strong>One Outs</strong>]
# [<strong>Death Parade</strong>]
# [<p class="title-english title-inherit">Kaiji: Ultimate Survivor</p>]
# [<p class="title-english title-inherit">The Promised Neverland</p>]
# [<p class="title-english title-inherit">Hell Girl</p>]
# [<p class="title-english title-inherit">No Game, No Life</p>]
# [<p class="title-english title-inherit">Inuyashiki: Last Hero</p>]
# [<p class="title-english title-inherit">Kaguya-sama: Love is War</p>]
# [<p class="title-english title-inherit">Case Closed</p>]
# [<strong>Another</strong>]
# [<strong>Durarara!!</strong>]
# [<strong>Steins;Gate</strong>]
# [<p class="title-english title-inherit">Parasyte -the maxim-</p>]
# [<p class="title-english title-inherit">Black Butler</p>]
# [<strong>Munou na Nana</strong>]
# [<p class="title-english title-inherit">Eden of The East</p>]
# [<p class="title-english title-inherit">ERASED</p>]
# [<p class="title-english title-inherit">Darker than Black</p>]
# [<strong>Aoi Bungaku Series</strong>]
# Death Note Done

# %%
ani_recs
# Out:
# {'Attack on Titan': ['Kabaneri of the Iron Fortress',
#   'Seraph of the End: Vampire Reign',
#   'Black Bullet',
#   'The Promised Neverland',
#   'Tokyo Ghoul',
#   'Knights of Sidonia',
#   'Fullmetal Alchemist: Brotherhood',
#   'Claymore',
#   'God Eater',
#   'Aldnoah.Zero',
#   'Neon Genesis Evangelion',
#   'Akame ga Kill!',
#   'Deadman Wonderland',
#   'Demon Slayer: Kimetsu no Yaiba',
#   'Vinland Saga',
#   'Berserk',
#   'Highschool of the Dead',
#   'Gurren Lagann'],
#  'Fullmetal Alchemist: Brotherhood': ['Hunter x Hunter',
#   'Attack on Titan',
#   'D.Gray-man',
#   'Blue Exorcist',
#   'Code Geass: Lelouch of the Rebellion',
#   'Baccano!',
#   'Demon Slayer: Kimetsu no Yaiba'],
#  'Haikyu!!': ["Kuroko's Basketball",
#   'Ace of Diamond',
#   'My Hero Academia',
#   'Run with the Wind',
#   'Free! - Iwatobi Swim Club',
#   'Ahiru no Sora',
#   'Yowamushi Pedal',
#   'Big Windup!',
#   'Welcome to the Ballroom',
#   'Chihayafuru'],
#  'Demon Slayer: Kimetsu no Yaiba': ['Dororo',
#   'Jujutsu Kaisen (TV)',
#   'Bleach',
#   'Attack on Titan',
#   'Fullmetal Alchemist: Brotherhood',
#   'Hunter x Hunter'],
#  'Hunter x Hunter': ['Fullmetal Alchemist: Brotherhood',
#   'One Piece',
#   'Yu Yu Hakusho: Ghost Files',
#   'Naruto',
#   'Made in Abyss',
#   'Tower of God',
#   "JoJo's Bizarre Adventure",
#   'My Hero Academia',
#   'Magi: The Labyrinth of Magic',
#   'Naruto: Shippuden',
#   'Dragon Ball',
#   "JoJo's Bizarre Adventure: Stardust Crusaders",
#   'Demon Slayer: Kimetsu no Yaiba'],
#  'Noragami: Stray God': ['Kamisama Kiss',
#   'Blue Exorcist',
#   'Beyond the Boundary',
#   'The Devil is a Part-Timer!',
#   'Soul Eater',
#   'Blood Lad',
#   'Toilet-bound Hanako-kun',
#   'Bakemonogatari',
#   'Rurouni Kenshin'],
#  'One Piece': ['Fairy Tail',
#   'Hunter x Hunter',
#   'Naruto',
#   'Dragon Ball',
#   'Dragon Ball Z',
#   'Naruto: Shippuden',
#   'Toriko',
#   'Soul Eater',
#   'Bleach'],
#  "KonoSuba: God's Blessing on This Wonderful World!": ['Re:ZERO -Starting Life in Another World-',
#   'Is It Wrong to Try to Pick Up Girls in a Dungeon?',
#   'Cautious Hero: The Hero Is Overpowered but Overly Cautious',
#   'No Game, No Life',
#   'In Another World With My Smartphone',
#   'Princess Connect! Re:Dive',
#   'Sword Art Online'],
#  'Cowboy Bebop': ['Samurai Champloo',
#   'Trigun',
#   'Black Lagoon',
#   'Outlaw Star',
#   'Space Dandy',
#   'Baccano!',
#   'Michiko & Hatchin',
#   'Darker than Black',
#   'Psycho-Pass',
#   'Gintama'],
#  'Vinland Saga': ['Attack on Titan'],
#  'Code Geass: Lelouch of the Rebellion': ['Death Note',
#   'Guilty Crown',
#   'Aldnoah.Zero',
#   'No Game, No Life',
#   'Mobile Suit Gundam 00',
#   'Legend of the Galactic Heroes',
#   'Valvrave the Liberator',
#   'Gurren Lagann',
#   'Fullmetal Alchemist: Brotherhood',
#   'Darker than Black',
#   'Big Order (TV)',
#   'Mobile Suit Gundam SEED',
#   'Neon Genesis Evangelion',
#   'Terror in Resonance',
#   'Eureka Seven',
#   'Full Metal Panic!',
#   'Akame ga Kill!'],
#  'Great Teacher Onizuka': ['Golden Boy',
#   'Assassination Classroom',
#   'Gintama',
#   'The Gokusen'],
#  'Mushi-Shi': ["Natsume's Book of Friends",
#   "Kino's Journey",
#   'Mononoke',
#   'Princess Mononoke',
#   'xxxHOLiC',
#   'Aria the Animation'],
#  'My Hero Academia': ['One Punch Man',
#   'Black Clover',
#   'Naruto',
#   'Assassination Classroom',
#   'Haikyu!!',
#   'Hunter x Hunter',
#   'Tiger & Bunny',
#   'Little Witch Academia',
#   'Charlotte',
#   'Fire Force'],
#  'One Punch Man': ['Mob Psycho 100',
#   'My Hero Academia',
#   'The Disastrous Life of Saiki K.',
#   'Overlord',
#   'Gintama',
#   'The Devil is a Part-Timer!'],
#  'Tokyo Ghoul': ['Parasyte -the maxim-',
#   'Ajin: Demi-Human',
#   'Attack on Titan',
#   'Deadman Wonderland',
#   'Shiki',
#   "Devils' Line",
#   'Pupa',
#   'Akame ga Kill!'],
#  'Bleach': ['Yu Yu Hakusho: Ghost Files',
#   'Naruto: Shippuden',
#   'Naruto',
#   'D.Gray-man',
#   'Soul Eater',
#   'Buso Renkin',
#   'Claymore',
#   'Demon Slayer: Kimetsu no Yaiba',
#   'One Piece'],
#  'Mob Psycho 100': ['One Punch Man',
#   'The Disastrous Life of Saiki K.',
#   'Hinamatsuri'],
#  'Psycho-Pass': ['Death Note',
#   'Ghost in the Shell: Stand Alone Complex',
#   'From the New World',
#   'Ergo Proxy',
#   'Id:Invaded',
#   'Terror in Resonance',
#   'Ghost in the Shell',
#   'Death Parade',
#   'Monster',
#   'Cowboy Bebop',
#   'Darker than Black',
#   'B: The Beginning'],
#  'Fate/Zero': ['The Future Diary',
#   'Puella Magi Madoka Magica',
#   'the Garden of sinners Chapter 1: Overlooking View',
#   'Re:Creators'],
#  "JoJo's Bizarre Adventure": ['Hunter x Hunter',
#   'Fist of the North Star',
#   'Kaiji: Ultimate Survivor'],
#  'My Teen Romantic Comedy SNAFU': ['Hyouka',
#   'Classroom of the Elite',
#   "Haganai: I don't have many friends",
#   'Rascal Does Not Dream of Bunny Girl Senpai',
#   'Bakemonogatari',
#   'Toradora!',
#   "WataMote: No Matter How I Look At It, It's You Guys' Fault I'm Unpopular!",
#   'Oreshura'],
#  'Rascal Does Not Dream of Bunny Girl Senpai': ['Bakemonogatari',
#   'My Teen Romantic Comedy SNAFU',
#   'Kokoro Connect',
#   'The Melancholy of Haruhi Suzumiya',
#   'Clannad'],
#  'Kaguya-sama: Love is War': ['Teasing Master Takagi-san',
#   'Death Note',
#   'Science Fell in Love, So I Tried to Prove It'],
#  "Kuroko's Basketball": ['Haikyu!!',
#   'Free! - Iwatobi Swim Club',
#   'Slam Dunk',
#   'The Prince of Tennis'],
#  'Gintama': ['SKET Dance',
#   'Daily Lives of High School Boys',
#   'The Disastrous Life of Saiki K.',
#   'Beelzebub',
#   'Rurouni Kenshin',
#   'One Punch Man',
#   'Hayate the Combat Butler',
#   'Great Teacher Onizuka',
#   'Cowboy Bebop',
#   'Good Luck Girl!'],
#  'Baccano!': ['Durarara!!',
#   '91 Days',
#   'Cowboy Bebop',
#   'Fullmetal Alchemist: Brotherhood',
#   'Fullmetal Alchemist',
#   'Black Lagoon'],
#  'Blood Blockade Battlefront': ['Bungo Stray Dogs'],
#  'Steins;Gate': ['ERASED',
#   'Re:ZERO -Starting Life in Another World-',
#   'Puella Magi Madoka Magica',
#   'The Future Diary',
#   'The Girl Who Leapt Through Time',
#   'Welcome to the N.H.K.',
#   'When They Cry',
#   'When They Cry: Kai',
#   'Death Note',
#   'Noein: to your other self'],
#  'March comes in like a lion': ['Your Lie in April',
#   'Chihayafuru',
#   'Honey and Clover',
#   "Natsume's Book of Friends"],
#  'Your Lie in April': ['March comes in like a lion',
#   'Nodame Cantabile',
#   'Clannad ~After Story~',
#   'I want to eat your pancreas',
#   'anohana: The Flower We Saw That Day',
#   'Kids on the Slope',
#   'Plastic Memories',
#   'Angel Beats!',
#   'Violet Evergarden',
#   'White Album 2',
#   'The Pet Girl of Sakurasou',
#   'Sound! Euphonium'],
#  'Monster': ['Death Note',
#   'Psycho-Pass',
#   'Gankutsuou: The Count of Monte Cristo'],
#  'Re:ZERO -Starting Life in Another World-': ['Steins;Gate',
#   "KonoSuba: God's Blessing on This Wonderful World!",
#   'ERASED',
#   'The Rising of the Shield Hero',
#   'Puella Magi Madoka Magica',
#   'When They Cry',
#   'Sword Art Online'],
#  'Death Note': ['Code Geass: Lelouch of the Rebellion',
#   'Monster',
#   'Terror in Resonance',
#   'The Future Diary',
#   'Psycho-Pass',
#   'Code Geass: Lelouch of the Rebellion R2',
#   'One Outs',
#   'Death Parade',
#   'Kaiji: Ultimate Survivor',
#   'The Promised Neverland',
#   'Hell Girl',
#   'No Game, No Life',
#   'Inuyashiki: Last Hero',
#   'Kaguya-sama: Love is War',
#   'Case Closed',
#   'Another',
#   'Durarara!!',
#   'Steins;Gate',
#   'Parasyte -the maxim-',
#   'Black Butler',
#   'Munou na Nana',
#   'Eden of The East',
#   'ERASED',
#   'Darker than Black',
#   'Aoi Bungaku Series']}

# %%
# Problem Children: My Hero Academia, Jojos
# My hero academia search term only pulls up season 3 result first for some reason, so manually input it
# For some reason, jojo's adds ?suggestion= into the url, manually input it
#url = google_search("Jojo's Bizzare Adventure MAL", my_api_key, my_cse_id)
#print(url)
# Out:
# https://myanimelist.net/anime/14719/JoJo_no_Kimyou_na_Bouken_TV?suggestion=/userrecs

# %%
# Old version that included the recommendation count
with open('ani_recs.pickle', 'wb') as handle:
    pickle.dump(ani_recs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# New version with just recommendation names
with open('ani_recs_new.pickle', 'wb') as handle:
    pickle.dump(ani_recs, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
nx_obj = nx.Graph(ani_recs)
#print("Fate Zero" in list(nx_obj.nodes()))
#nx_obj.edges()
for edge in nx_obj.edges():
    print(edge[0], edge[1])
    #print(ani_recs[edge[0]][edge[1]])
#nx_obj.nodes['title'] = list(nx_obj.nodes())
# Out:
# Attack on Titan Kabaneri of the Iron Fortress
# Attack on Titan Seraph of the End: Vampire Reign
# Attack on Titan Black Bullet
# Attack on Titan The Promised Neverland
# Attack on Titan Tokyo Ghoul
# Attack on Titan Knights of Sidonia
# Attack on Titan Fullmetal Alchemist: Brotherhood
# Attack on Titan Claymore
# Attack on Titan God Eater
# Attack on Titan Aldnoah.Zero
# Attack on Titan Neon Genesis Evangelion
# Attack on Titan Akame ga Kill!
# Attack on Titan Deadman Wonderland
# Attack on Titan Demon Slayer: Kimetsu no Yaiba
# Attack on Titan Vinland Saga
# Attack on Titan Berserk
# Attack on Titan Highschool of the Dead
# Attack on Titan Gurren Lagann
# Fullmetal Alchemist: Brotherhood Hunter x Hunter
# Fullmetal Alchemist: Brotherhood D.Gray-man
# Fullmetal Alchemist: Brotherhood Blue Exorcist
# Fullmetal Alchemist: Brotherhood Code Geass: Lelouch of the Rebellion
# Fullmetal Alchemist: Brotherhood Baccano!
# Fullmetal Alchemist: Brotherhood Demon Slayer: Kimetsu no Yaiba
# Haikyu!! Kuroko's Basketball
# Haikyu!! Ace of Diamond
# Haikyu!! My Hero Academia
# Haikyu!! Run with the Wind
# Haikyu!! Free! - Iwatobi Swim Club
# Haikyu!! Ahiru no Sora
# Haikyu!! Yowamushi Pedal
# Haikyu!! Big Windup!
# Haikyu!! Welcome to the Ballroom
# Haikyu!! Chihayafuru
# Demon Slayer: Kimetsu no Yaiba Dororo
# Demon Slayer: Kimetsu no Yaiba Jujutsu Kaisen (TV)
# Demon Slayer: Kimetsu no Yaiba Bleach
# Demon Slayer: Kimetsu no Yaiba Hunter x Hunter
# Hunter x Hunter One Piece
# Hunter x Hunter Yu Yu Hakusho: Ghost Files
# Hunter x Hunter Naruto
# Hunter x Hunter Made in Abyss
# Hunter x Hunter Tower of God
# Hunter x Hunter JoJo's Bizarre Adventure
# Hunter x Hunter My Hero Academia
# Hunter x Hunter Magi: The Labyrinth of Magic
# Hunter x Hunter Naruto: Shippuden
# Hunter x Hunter Dragon Ball
# Hunter x Hunter JoJo's Bizarre Adventure: Stardust Crusaders
# Noragami: Stray God Kamisama Kiss
# Noragami: Stray God Blue Exorcist
# Noragami: Stray God Beyond the Boundary
# Noragami: Stray God The Devil is a Part-Timer!
# Noragami: Stray God Soul Eater
# Noragami: Stray God Blood Lad
# Noragami: Stray God Toilet-bound Hanako-kun
# Noragami: Stray God Bakemonogatari
# Noragami: Stray God Rurouni Kenshin
# One Piece Fairy Tail
# One Piece Naruto
# One Piece Dragon Ball
# One Piece Dragon Ball Z
# One Piece Naruto: Shippuden
# One Piece Toriko
# One Piece Soul Eater
# One Piece Bleach
# KonoSuba: God's Blessing on This Wonderful World! Re:ZERO -Starting Life in Another World-
# KonoSuba: God's Blessing on This Wonderful World! Is It Wrong to Try to Pick Up Girls in a Dungeon?
# KonoSuba: God's Blessing on This Wonderful World! Cautious Hero: The Hero Is Overpowered but Overly Cautious
# KonoSuba: God's Blessing on This Wonderful World! No Game, No Life
# KonoSuba: God's Blessing on This Wonderful World! In Another World With My Smartphone
# KonoSuba: God's Blessing on This Wonderful World! Princess Connect! Re:Dive
# KonoSuba: God's Blessing on This Wonderful World! Sword Art Online
# Cowboy Bebop Samurai Champloo
# Cowboy Bebop Trigun
# Cowboy Bebop Black Lagoon
# Cowboy Bebop Outlaw Star
# Cowboy Bebop Space Dandy
# Cowboy Bebop Baccano!
# Cowboy Bebop Michiko & Hatchin
# Cowboy Bebop Darker than Black
# Cowboy Bebop Psycho-Pass
# Cowboy Bebop Gintama
# Code Geass: Lelouch of the Rebellion Death Note
# Code Geass: Lelouch of the Rebellion Guilty Crown
# Code Geass: Lelouch of the Rebellion Aldnoah.Zero
# Code Geass: Lelouch of the Rebellion No Game, No Life
# Code Geass: Lelouch of the Rebellion Mobile Suit Gundam 00
# Code Geass: Lelouch of the Rebellion Legend of the Galactic Heroes
# Code Geass: Lelouch of the Rebellion Valvrave the Liberator
# Code Geass: Lelouch of the Rebellion Gurren Lagann
# Code Geass: Lelouch of the Rebellion Darker than Black
# Code Geass: Lelouch of the Rebellion Big Order (TV)
# Code Geass: Lelouch of the Rebellion Mobile Suit Gundam SEED
# Code Geass: Lelouch of the Rebellion Neon Genesis Evangelion
# Code Geass: Lelouch of the Rebellion Terror in Resonance
# Code Geass: Lelouch of the Rebellion Eureka Seven
# Code Geass: Lelouch of the Rebellion Full Metal Panic!
# Code Geass: Lelouch of the Rebellion Akame ga Kill!
# Great Teacher Onizuka Golden Boy
# Great Teacher Onizuka Assassination Classroom
# Great Teacher Onizuka Gintama
# Great Teacher Onizuka The Gokusen
# Mushi-Shi Natsume's Book of Friends
# Mushi-Shi Kino's Journey
# Mushi-Shi Mononoke
# Mushi-Shi Princess Mononoke
# Mushi-Shi xxxHOLiC
# Mushi-Shi Aria the Animation
# My Hero Academia One Punch Man
# My Hero Academia Black Clover
# My Hero Academia Naruto
# My Hero Academia Assassination Classroom
# My Hero Academia Tiger & Bunny
# My Hero Academia Little Witch Academia
# My Hero Academia Charlotte
# My Hero Academia Fire Force
# One Punch Man Mob Psycho 100
# One Punch Man The Disastrous Life of Saiki K.
# One Punch Man Overlord
# One Punch Man Gintama
# One Punch Man The Devil is a Part-Timer!
# Tokyo Ghoul Parasyte -the maxim-
# Tokyo Ghoul Ajin: Demi-Human
# Tokyo Ghoul Deadman Wonderland
# Tokyo Ghoul Shiki
# Tokyo Ghoul Devils' Line
# Tokyo Ghoul Pupa
# Tokyo Ghoul Akame ga Kill!
# Bleach Yu Yu Hakusho: Ghost Files
# Bleach Naruto: Shippuden
# Bleach Naruto
# Bleach D.Gray-man
# Bleach Soul Eater
# Bleach Buso Renkin
# Bleach Claymore
# Mob Psycho 100 The Disastrous Life of Saiki K.
# Mob Psycho 100 Hinamatsuri
# Psycho-Pass Death Note
# Psycho-Pass Ghost in the Shell: Stand Alone Complex
# Psycho-Pass From the New World
# Psycho-Pass Ergo Proxy
# Psycho-Pass Id:Invaded
# Psycho-Pass Terror in Resonance
# Psycho-Pass Ghost in the Shell
# Psycho-Pass Death Parade
# Psycho-Pass Monster
# Psycho-Pass Darker than Black
# Psycho-Pass B: The Beginning
# Fate/Zero The Future Diary
# Fate/Zero Puella Magi Madoka Magica
# Fate/Zero the Garden of sinners Chapter 1: Overlooking View
# Fate/Zero Re:Creators
# JoJo's Bizarre Adventure Fist of the North Star
# JoJo's Bizarre Adventure Kaiji: Ultimate Survivor
# My Teen Romantic Comedy SNAFU Hyouka
# My Teen Romantic Comedy SNAFU Classroom of the Elite
# My Teen Romantic Comedy SNAFU Haganai: I don't have many friends
# My Teen Romantic Comedy SNAFU Rascal Does Not Dream of Bunny Girl Senpai
# My Teen Romantic Comedy SNAFU Bakemonogatari
# My Teen Romantic Comedy SNAFU Toradora!
# My Teen Romantic Comedy SNAFU WataMote: No Matter How I Look At It, It's You Guys' Fault I'm Unpopular!
# My Teen Romantic Comedy SNAFU Oreshura
# Rascal Does Not Dream of Bunny Girl Senpai Bakemonogatari
# Rascal Does Not Dream of Bunny Girl Senpai Kokoro Connect
# Rascal Does Not Dream of Bunny Girl Senpai The Melancholy of Haruhi Suzumiya
# Rascal Does Not Dream of Bunny Girl Senpai Clannad
# Kaguya-sama: Love is War Teasing Master Takagi-san
# Kaguya-sama: Love is War Death Note
# Kaguya-sama: Love is War Science Fell in Love, So I Tried to Prove It
# Kuroko's Basketball Free! - Iwatobi Swim Club
# Kuroko's Basketball Slam Dunk
# Kuroko's Basketball The Prince of Tennis
# Gintama SKET Dance
# Gintama Daily Lives of High School Boys
# Gintama The Disastrous Life of Saiki K.
# Gintama Beelzebub
# Gintama Rurouni Kenshin
# Gintama Hayate the Combat Butler
# Gintama Good Luck Girl!
# Baccano! Durarara!!
# Baccano! 91 Days
# Baccano! Fullmetal Alchemist
# Baccano! Black Lagoon
# Blood Blockade Battlefront Bungo Stray Dogs
# Steins;Gate ERASED
# Steins;Gate Re:ZERO -Starting Life in Another World-
# Steins;Gate Puella Magi Madoka Magica
# Steins;Gate The Future Diary
# Steins;Gate The Girl Who Leapt Through Time
# Steins;Gate Welcome to the N.H.K.
# Steins;Gate When They Cry
# Steins;Gate When They Cry: Kai
# Steins;Gate Death Note
# Steins;Gate Noein: to your other self
# March comes in like a lion Your Lie in April
# March comes in like a lion Chihayafuru
# March comes in like a lion Honey and Clover
# March comes in like a lion Natsume's Book of Friends
# Your Lie in April Nodame Cantabile
# Your Lie in April Clannad ~After Story~
# Your Lie in April I want to eat your pancreas
# Your Lie in April anohana: The Flower We Saw That Day
# Your Lie in April Kids on the Slope
# Your Lie in April Plastic Memories
# Your Lie in April Angel Beats!
# Your Lie in April Violet Evergarden
# Your Lie in April White Album 2
# Your Lie in April The Pet Girl of Sakurasou
# Your Lie in April Sound! Euphonium
# Monster Death Note
# Monster Gankutsuou: The Count of Monte Cristo
# Re:ZERO -Starting Life in Another World- ERASED
# Re:ZERO -Starting Life in Another World- The Rising of the Shield Hero
# Re:ZERO -Starting Life in Another World- Puella Magi Madoka Magica
# Re:ZERO -Starting Life in Another World- When They Cry
# Re:ZERO -Starting Life in Another World- Sword Art Online
# Death Note Terror in Resonance
# Death Note The Future Diary
# Death Note Code Geass: Lelouch of the Rebellion R2
# Death Note One Outs
# Death Note Death Parade
# Death Note Kaiji: Ultimate Survivor
# Death Note The Promised Neverland
# Death Note Hell Girl
# Death Note No Game, No Life
# Death Note Inuyashiki: Last Hero
# Death Note Case Closed
# Death Note Another
# Death Note Durarara!!
# Death Note Parasyte -the maxim-
# Death Note Black Butler
# Death Note Munou na Nana
# Death Note Eden of The East
# Death Note ERASED
# Death Note Darker than Black
# Death Note Aoi Bungaku Series

# %%
g = Network(height = 800, width = 800, notebook = True)
#g.toggle_hide_edges_on_drag(False)
#g.barnes_hut()
g.from_nx(nx.Graph(ani_recs))
g.set_options("""
var options = {
  "nodes": {
    "font": {
      "size": 17,
      "background": "rgba(255,255,255,1)"
    }
  },
  "edges": {
    "color": {
      "inherit": true
    },
    "smooth": false
  },
  "interaction": {
    "hover": true,
    "keyboard": {
      "enabled": true
    },
    "navigationButtons": true
  },
  "physics": {
    "forceAtlas2Based": {
      "springLength": 100
    },
    "minVelocity": 0.75,
    "solver": "forceAtlas2Based"
  }
}
""")


g.show("ex.html")
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="ex.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
with open('ani_recs_new.pickle', 'rb') as handle:
    a_recs = pickle.load(handle)

# %%
print(a_recs["Fullmetal Alchemist Brotherhood"]['Code Geass: Hangyaku no Lelouch'])
# Out:
# 15

# %%
g = nx.Graph(a_recs)
"""
neighbors = g["Baccano!"]
print(a_recs["Baccano!"]['Fullmetal Alchemist: Brotherhood'])

if("Baccano!" in a_recs.keys()):
    recs_total = [a_recs["Baccano!"][n] for n in list(neighbors)]
    data = {'Recommendations': list(neighbors), '# Recs': recs_total}
    print(data)
"""
# Out:
# '\nneighbors = g["Baccano!"]\nprint(a_recs["Baccano!"][\'Fullmetal Alchemist: Brotherhood\'])\n\nif("Baccano!" in a_recs.keys()):\n    recs_total = [a_recs["Baccano!"][n] for n in list(neighbors)]\n    data = {\'Recommendations\': list(neighbors), \'# Recs\': recs_total}\n    print(data)\n'

# %%
resp = requests.get("https://www.crunchyroll.com/videos/anime/alpha?group=all")
# get BeautifulSoup object
soup = BeautifulSoup(resp.content, 'html.parser')
# Get the titles of the user recommended animes
links = soup.select("h3")
recs = [title.text for title in links]
print(recs)
# Out:
# []

# %%
# Gets Anime List for Given Service
def getList(url, offset):
    resp = requests.get(url)
    search_term = ".css-1u7zfla a"
    # get BeautifulSoup object
    soup = BeautifulSoup(resp.content, 'html.parser')
    # Get the titles of the user recommended animes
    links = soup.select(search_term)
    recs = [title.text for title in links]
    for i in range(50,offset+1,50):
        url = url + "?offset=" + str(i)
        resp = requests.get(url)
        # get BeautifulSoup object
        soup = BeautifulSoup(resp.content, 'html.parser')
        # Get the titles of the user recommended animes
        links = soup.select(search_term)
        recs.extend([title.text for title in links])
    return recs

# Crunchyroll

crunch_list = getList("https://reelgood.com/source/crunchyroll", 600)
print(crunch_list)
# Out:
# ['Attack on Titan', 'My Hero Academia', 'Fullmetal Alchemist: Brotherhood', 'Demon Slayer: Kimetsu no Yaiba', 'The Promised Neverland', 'Death Note', 'One-Punch Man', 'Naruto Shippūden', 'Hunter x Hunter', 'One Piece', 'Naruto', 'Haikyu!!', 'Food Wars! Shokugeki no Soma', "Kuroko's Basketball", 'Bleach', 'Sword Art Online', 'Fairy Tail', 'ERASED', 'Dragon Ball Super', 'Case Closed', 'Mob Psycho 100', "JoJo's Bizarre Adventure", 'Another', 'Black Clover', 'Golden Time', 'Dr. Stone', 'Parasyte -the maxim-', 'Your Lie in April', 'InuYasha', 'Rascal Does Not Dream of Bunny Girl Senpai', "DAKAICHI -I'm being harassed by the sexiest man of the year-", 'Anohana: The Flower We Saw That Day', 'Re:ZERO -Starting Life in Another World-', 'Psycho-Pass', 'Kaguya-sama: Love is War', 'Akame ga Kill!', 'The Last: Naruto the Movie', 'Diabolik Lovers', 'Monster Musume: Everyday Life with Monster Girls', 'Boruto: Naruto Next Generations', 'The Rising of the Shield Hero', 'Gintama', 'Yuri!!! on Ice', 'No. 6', 'Overlord', 'KonoSuba – God’s blessing on this wonderful world!!', 'DARLING in the FRANXX', 'Fire Force', 'Toradora!', 'Digimon Adventure', 'Blue Spring Ride', 'Darker than Black', 'That Time I Got Reincarnated as a Slime', 'Naruto Shippuden the Movie: Road to Ninja', 'Fruits Basket', 'The Pet Girl of Sakurasou', 'Given', 'My Teen Romantic Comedy SNAFU', 'Kill la Kill', 'Saint Seiya', 'Gurren Lagann', 'Fate/Zero', 'Yu-Gi-Oh! GX', 'Is It Wrong to Try to Pick Up Girls in a Dungeon?', 'Ergo Proxy', 'No Game No Life', 'My Little Monster', 'Puella Magi Madoka Magica', 'The Disastrous Life of Saiki K.', 'Angel Beats!', 'Junjo Romantica', 'Log Horizon', 'Inu x Boku Secret Service', 'The Irregular at Magic High School', 'Goblin Slayer', 'Monogatari', 'Lupin the Third', 'K-Project', 'Cells at Work!', 'Cardcaptor Sakura', 'Charlotte', 'Nisekoi', 'Bungo Stray Dogs', 'The Fruit of Grisaia', 'Magi', 'Blue Exorcist', 'Durarara!!', 'The Quintessential Quintuplets', 'Vampire Knight', 'Fist of the North Star', 'Strike the Blood', 'Naruto the Movie: Ninja Clash in the Land of Snow', 'Tower of God', 'Star Blazers', 'The Familiar of Zero', 'Yu-Gi-Oh!', 'RWBY', 'Yona of the Dawn', 'Sailor Moon Crystal', 'Fate/stay night', 'Attack on Titan', 'My Hero Academia', 'Fullmetal Alchemist: Brotherhood', 'Demon Slayer: Kimetsu no Yaiba', 'The Promised Neverland', 'Death Note', 'One-Punch Man', 'Naruto Shippūden', 'Hunter x Hunter', 'One Piece', 'Naruto', 'Haikyu!!', 'Food Wars! Shokugeki no Soma', "Kuroko's Basketball", 'Bleach', 'Sword Art Online', 'Fairy Tail', 'ERASED', 'Dragon Ball Super', 'Case Closed', 'Mob Psycho 100', "JoJo's Bizarre Adventure", 'Another', 'Black Clover', 'Golden Time', 'Dr. Stone', 'Parasyte -the maxim-', 'Your Lie in April', 'InuYasha', 'Rascal Does Not Dream of Bunny Girl Senpai', "DAKAICHI -I'm being harassed by the sexiest man of the year-", 'Anohana: The Flower We Saw That Day', 'Re:ZERO -Starting Life in Another World-', 'Psycho-Pass', 'Kaguya-sama: Love is War', 'Akame ga Kill!', 'The Last: Naruto the Movie', 'Diabolik Lovers', 'Monster Musume: Everyday Life with Monster Girls', 'Boruto: Naruto Next Generations', 'The Rising of the Shield Hero', 'Gintama', 'Yuri!!! on Ice', 'No. 6', 'Overlord', 'KonoSuba – God’s blessing on this wonderful world!!', 'DARLING in the FRANXX', 'Fire Force', 'Toradora!', 'Digimon Adventure', 'Attack on Titan', 'My Hero Academia', 'Fullmetal Alchemist: Brotherhood', 'Demon Slayer: Kimetsu no Yaiba', 'The Promised Neverland', 'Death Note', 'One-Punch Man', 'Naruto Shippūden', 'Hunter x Hunter', 'One Piece', 'Naruto', 'Haikyu!!', 'Food Wars! Shokugeki no Soma', "Kuroko's Basketball", 'Bleach', 'Sword Art Online', 'Fairy Tail', 'ERASED', 'Dragon Ball Super', 'Case Closed', 'Mob Psycho 100', "JoJo's Bizarre Adventure", 'Another', 'Black Clover', 'Golden Time', 'Dr. Stone', 'Parasyte -the maxim-', 'Your Lie in April', 'InuYasha', 'Rascal Does Not Dream of Bunny Girl Senpai', "DAKAICHI -I'm being harassed by the sexi ...

# %%
# Netflix
#lscf-posts-container-defaultTheme a
"https://netflixanime.com/"
netflix_list = getList("https://reelgood.com/genre/anime/on-netflix", 100)
#print(netflix_list)

# %%
#Prime Video
".css-1u7zfla a"
"https://reelgood.com/genre/anime/on-amazon?offset=50"
prime_list = getList("https://reelgood.com/genre/anime/on-amazon", 50)
#print(prime_list)

# %%
#Funimation
funimation_list = getList("https://reelgood.com/source/funimation", 550)
#print(funimation_list)

# %%
#HBO Max
hbo_list = getList("https://reelgood.com/genre/anime/on-hbo_max", 50)
#print(hbo_list)

# %%
hulu_list = getList("https://reelgood.com/genre/anime/on-hulu", 150)
#print(hulu_list)

# %%
animes = list(g.nodes())
watch_on = dict()
for anime in animes:
    watch_on[anime] = list()
    
    if(difflib.get_close_matches(anime, crunch_list, cutoff = 0.8)):
        watch_on[anime].append("crunchyroll")
    if(difflib.get_close_matches(anime, netflix_list, cutoff = 0.8)):
        watch_on[anime].append("netflix")
    if(difflib.get_close_matches(anime, prime_list, cutoff = 0.8)):
        watch_on[anime].append("prime")
    if(difflib.get_close_matches(anime, funimation_list, cutoff = 0.8)):
        watch_on[anime].append("funimation")
    if(difflib.get_close_matches(anime, hbo_list, cutoff = 0.8)):
        watch_on[anime].append("HBO MAX")
    if(difflib.get_close_matches(anime, hulu_list, cutoff = 0.8)):
        watch_on[anime].append("hulu")

# %%
watch_on

#reel good doesn't have a lot of anime on it, 
#so get more comprehensive lists (probably just for netflix, crunchyroll, and funimation)
# Out:
# {'Attack on Titan': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  'Fullmetal Alchemist: Brotherhood': ['crunchyroll',
#   'netflix',
#   'funimation',
#   'HBO MAX',
#   'hulu'],
#  'Haikyu!!': ['crunchyroll', 'netflix', 'hulu'],
#  'Demon Slayer: Kimetsu no Yaiba': ['crunchyroll', 'funimation', 'hulu'],
#  'Hunter x Hunter': ['crunchyroll', 'netflix', 'HBO MAX', 'hulu'],
#  'Noragami: Stray God': [],
#  'One Piece': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  "KonoSuba: God's Blessing on This Wonderful World!": ['crunchyroll',
#   'HBO MAX'],
#  'Cowboy Bebop': ['funimation', 'hulu'],
#  'Vinland Saga': ['prime'],
#  'Code Geass: Lelouch of the Rebellion': ['netflix', 'funimation'],
#  'Great Teacher Onizuka': ['prime'],
#  'Mushi-Shi': ['prime', 'funimation', 'hulu'],
#  'My Hero Academia': ['crunchyroll', 'funimation', 'hulu'],
#  'One Punch Man': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  'Tokyo Ghoul': ['funimation', 'hulu'],
#  'Bleach': ['crunchyroll', 'netflix', 'hulu'],
#  'Mob Psycho 100': ['crunchyroll', 'funimation', 'HBO MAX'],
#  'Psycho-Pass': ['crunchyroll', 'prime', 'funimation', 'hulu'],
#  'Fate/Zero': ['crunchyroll', 'funimation'],
#  "JoJo's Bizarre Adventure": ['crunchyroll', 'netflix', 'hulu'],
#  'My Teen Romantic Comedy SNAFU': ['crunchyroll', 'hulu'],
#  'Rascal Does Not Dream of Bunny Girl Senpai': ['crunchyroll',
#   'funimation',
#   'hulu'],
#  'Kaguya-sama: Love is War': ['crunchyroll', 'funimation', 'hulu'],
#  "Kuroko's Basketball": ['crunchyroll', 'netflix'],
#  'Gintama': ['crunchyroll'],
#  'Baccano!': [],
#  'Blood Blockade Battlefront': [],
#  'Steins;Gate': ['funimation', 'hulu'],
#  'March comes in like a lion': ['netflix'],
#  'Your Lie in April': ['crunchyroll',
#   'netflix',
#   'funimation',
#   'HBO MAX',
#   'hulu'],
#  'Monster': [],
#  'Re:ZERO -Starting Life in Another World-': ['crunchyroll', 'HBO MAX'],
#  'Death Note': ['crunchyroll', 'netflix', 'funimation', 'HBO MAX', 'hulu'],
#  'Kabaneri of the Iron Fortress': ['HBO MAX'],
#  'Seraph of the End: Vampire Reign': [],
#  'Black Bullet': ['netflix', 'funimation', 'hulu'],
#  'The Promised Neverland': ['crunchyroll',
#   'netflix',
#   'funimation',
#   'HBO MAX',
#   'hulu'],
#  'Knights of Sidonia': ['netflix'],
#  'Claymore': ['funimation'],
#  'God Eater': ['netflix'],
#  'Aldnoah.Zero': ['HBO MAX'],
#  'Neon Genesis Evangelion': ['netflix'],
#  'Akame ga Kill!': ['crunchyroll', 'netflix', 'hulu'],
#  'Deadman Wonderland': ['funimation'],
#  'Berserk': ['HBO MAX'],
#  'Highschool of the Dead': ['hulu'],
#  'Gurren Lagann': ['crunchyroll', 'funimation'],
#  'D.Gray-man': [],
#  'Blue Exorcist': ['crunchyroll', 'netflix', 'funimation', 'HBO MAX', 'hulu'],
#  'Ace of Diamond': [],
#  'Run with the Wind': [],
#  'Free! - Iwatobi Swim Club': [],
#  'Ahiru no Sora': [],
#  'Yowamushi Pedal': [],
#  'Big Windup!': [],
#  'Welcome to the Ballroom': ['prime'],
#  'Chihayafuru': [],
#  'Dororo': ['prime'],
#  'Jujutsu Kaisen (TV)': [],
#  'Yu Yu Hakusho: Ghost Files': [],
#  'Naruto': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  'Made in Abyss': ['prime'],
#  'Tower of God': ['crunchyroll', 'HBO MAX'],
#  'Magi: The Labyrinth of Magic': [],
#  'Naruto: Shippuden': ['crunchyroll', 'hulu'],
#  'Dragon Ball': ['funimation', 'hulu'],
#  "JoJo's Bizarre Adventure: Stardust Crusaders": [],
#  'Kamisama Kiss': ['funimation', 'hulu'],
#  'Beyond the Boundary': [],
#  'The Devil is a Part-Timer!': ['netflix', 'funimation'],
#  'Soul Eater': ['netflix', 'funimation', 'hulu'],
#  'Blood Lad': [],
#  'Toilet-bound Hanako-kun': [],
#  'Bakemonogatari': [],
#  'Rurouni Kenshin': ['prime', 'hulu'],
#  'Fairy Tail': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  'Dragon Ball Z': ['crunchyroll', 'funimation', 'hulu'],
#  'Toriko': [],
#  'Is It Wrong to Try to Pick Up Girls in a Dungeon?': ['crunchyroll',
#   'netflix',
#   'hulu'],
#  'Cautious Hero: The Hero Is Overpowered but Overly Cautious': [],
#  'No Game, No Life': ['crunchyroll', 'netflix', 'prime'],
#  'In Another World With My Smartphone': [],
#  'Princess Connect! Re:Dive': [],
#  'Sword Art Online': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  'Samurai Champloo': ['funimation', 'hulu'],
#  'Trigun': [],
#  'Black Lagoon': ['funimation', 'hulu'],
#  'Outlaw Star': [],
#  'Space Dandy': ['funimation', 'hulu'],
#  'Michiko & Hatchin': [],
#  'Darker than Black': ['crunchyroll', 'prime', 'hulu'],
#  'Guilty Crown': [],
#  'Mobile Suit Gundam 00': [],
#  'Legend of the Galactic Heroes': [],
#  'Valvrave the Liberator': [],
#  'Big Order (TV)': [],
#  'Mobile Suit Gundam SEED': [],
#  'Terror in Resonance': ['funimation'],
#  'Eureka Seven': [],
#  'Full Metal Panic!': ['funimation', 'hulu'],
#  'Golden Boy': [],
#  'Assassination Classroom': ['funimation', 'hulu'],
#  'The Gokusen': [],
#  "Natsume's Book of Friends": [],
#  "Kino's Journey": [],
#  'Mononoke': [],
#  'Princess Mononoke': ['HBO MAX'],
#  'xxxHOLiC': [],
#  'Aria the Animation': [],
#  'Black Clover': ['crunchyroll', 'funimation', 'hulu'],
#  'Tiger & Bunny': [],
#  'Little Witch Academia': ['netflix'],
#  'Charlotte': ['crunchyroll', 'funimation'],
#  'Fire Force': ['crunchyroll', 'funimation', 'hulu'],
#  'The Disastrous Life of Saiki K.': ['crunchyroll', 'funimation'],
#  'Overlord': ['crunchyroll', 'funimation', 'hulu'],
#  'Parasyte -the maxim-': ['crunchyroll', 'netflix', 'hulu'],
#  'Ajin: Demi-Human': [],
#  'Shiki': ['hulu'],
#  "Devils' Line": [],
#  'Pupa': [],
#  'Buso Renkin': [],
#  'Hinamatsuri': [],
#  'Ghost in the Shell: Stand Alone Complex': [],
#  'From the New World': [],
#  'Ergo Proxy': ['crunchyroll', 'funimation', 'hulu'],
#  'Id:Invaded': [],
#  'Ghost in the Shell': ['prime'],
#  'Death Parade': ['funimation'],
#  'B: The Beginning': ['netflix'],
#  'The Future Diary': ['funimation', 'hulu'],
#  'Puella Magi Madoka Magica': ['crunchyroll',
#   'netflix',
#   'funimation',
#   'HBO MAX',
#   'hulu'],
#  'the Garden of sinners Chapter 1: Overlooking View': [],
#  'Re:Creators': ['prime'],
#  'Fist of the North Star': ['crunchyroll'],
#  'Kaiji: Ultimate Survivor': [],
#  'Hyouka': ['funimation'],
#  'Classroom of the Elite': [],
#  "Haganai: I don't have many friends": [],
#  'Toradora!': ['crunchyroll', 'netflix', 'prime', 'funimation'],
#  "WataMote: No Matter How I Look At It, It's You Guys' Fault I'm Unpopular!": [],
#  'Oreshura': [],
#  'Kokoro Connect': [],
#  'The Melancholy of Haruhi Suzumiya': [],
#  'Clannad': ['netflix', 'hulu'],
#  'Teasing Master Takagi-san': ['funimation'],
#  'Science Fell in Love, So I Tried to Prove It': [],
#  'Slam Dunk': [],
#  'The Prince of Tennis': [],
#  'SKET Dance': [],
#  'Daily Lives of High School Boys': [],
#  'Beelzebub': [],
#  'Hayate the Combat Butler': [],
#  'Good Luck Girl!': [],
#  'Durarara!!': ['crunchyroll', 'netflix', 'funimation', 'hulu'],
#  '91 Days': ['HBO MAX'],
#  'Fullmetal Alchemist': ['netflix'],
#  'Bungo Stray Dogs': ['crunchyroll', 'funimation', 'HBO MAX'],
#  'ERASED': ['crunchyroll', 'netflix', 'funimation', 'HBO MAX', 'hulu'],
#  'The Girl Who Leapt Through Time': [],
#  'Welcome to the N.H.K.': [],
#  'When They Cry': [],
#  'When They Cry: Kai': [],
#  'Noein: to your other self': [],
#  'Honey and Clover': [],
#  'Nodame Cantabile': [],
#  'Clannad ~After Story~': [],
#  'I want to eat your pancreas': [],
#  'anohana: The Flower We Saw That Day': ['crunchyroll',
#   'netflix',
#   'funimation'],
#  'Kids on the Slope': [],
#  'Plastic Memories': ['hulu'],
#  'Angel Beats!': ['crunchyroll', 'netflix', 'prime', 'funimation'],
#  'Violet Evergarden': ['netflix'],
#  'White Album 2': [],
#  'The Pet Girl of Sakurasou': ['crunchyroll'],
#  'Sound! Euphonium': [],
#  'Gankutsuou: The Count of Monte Cristo': [],
#  'The Rising of the Shield Hero': ['crunchyroll', 'funimation'],
#  'Code Geass: Lelouch of the Rebellion R2': ['netflix', 'funimation'],
#  'One Outs': [],
#  'Hell Girl': ['prime'],
#  'Inuyashiki: Last Hero': [],
#  'Case Closed': ['crunchyroll', 'netflix'],
#  'Another': ['crunchyroll'],
#  'Black Butler': ['netflix', 'funimation', 'hulu'],
#  'Munou na Nana': [],
#  'Eden of The East': [],
#  'Aoi Bungaku Series': []}

# %%
with open('watch_on.pickle', 'wb') as handle:
    pickle.dump(watch_on, handle, protocol=pickle.HIGHEST_PROTOCOL)
